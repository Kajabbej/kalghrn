# %% [markdown]
# # Tugas: Singular Value Decomposition (SVD)
#
# ## Instruksi Tugas
# Selesaikan tugas di bawah ini menggunakan pustaka Python (NumPy/SciPy/SageMath) untuk menghitung Dekomposisi Nilai Singular (SVD) dari matriks yang diberikan.
#
# ### Soal
# Diberikan matriks $A$ sebagai berikut:
# $$
# A = \begin{bmatrix} 3 & 2 & 2 \\ 2 & 3 & -2 \end{bmatrix}
# $$
#
# 1. Carilah nilai singular dari matriks $A$.
# 2. Carilah matriks $U$, $\Sigma$, dan $V^T$ sedemikian rupa sehingga $A = U \Sigma V^T$.
# 3. Verifikasi hasil pemfaktoran Anda dengan mengalikan kembali matriks-matriks tersebut.

# %%
# Tuliskan kode penyelesaian Anda di sini
import numpy as np

# Definisikan matriks A
A = np.array([
    [3, 2, 2],
    [2, 3, -2]
])

# Hitung SVD
# U, S, Vt = np.linalg.svd(A)
