# %% [markdown]
# # Tugas Eliminasi Gaussian
#
# Halaman ini berisi penyelesaian tugas Eliminasi Gaussian untuk mata kuliah Aljabar Linear Komputasi.

# %%
# Tulis kode eliminasi Gaussian Anda di sini
import numpy as np
print("Eliminasi Gaussian")
