# %% [markdown]
# # Tugas: Dekomposisi QR
#
# ## Instruksi Tugas
# Selesaikan tugas di bawah ini menggunakan pustaka Python (NumPy/SciPy/SageMath) untuk menghitung Dekomposisi QR dari matriks yang diberikan.
#
# ### Soal
# Diberikan matriks $A$ sebagai berikut:
# $$
# A = \begin{bmatrix} 1 & 1 & 0 \\ 1 & 0 & 1 \\ 0 & 1 & 1 \end{bmatrix}
# $$
#
# 1. Carilah matriks ortogonal $Q$ dan matriks segitiga atas $R$ menggunakan metode Gram-Schmidt atau fungsi pustaka komputasi sehingga $A = QR$.
# 2. Verifikasi hasil dekomposisi Anda dengan memeriksa apakah $Q^T Q = I$ (identitas) dan $QR = A$.

# %%
# Tuliskan kode penyelesaian Anda di sini
import numpy as np

# Definisikan matriks A
A = np.array([
    [1, 1, 0],
    [1, 0, 1],
    [0, 1, 1]
])

# Hitung Dekomposisi QR
# Q, R = np.linalg.qr(A)
