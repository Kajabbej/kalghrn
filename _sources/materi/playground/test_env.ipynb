# %%
import os
import sys
print("sys.argv:", sys.argv)
print("sys.modules keys:", [k for k in sys.modules.keys() if 'sphinx' in k or 'jupyter' in k or 'nb' in k])
for k, v in os.environ.items():
    print(f"{k}={v}")
